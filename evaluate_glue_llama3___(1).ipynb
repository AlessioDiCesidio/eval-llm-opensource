# %%
# !pip install -q datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 12.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 21.1 MB/s eta 0:00:00

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_metric, load_dataset
from tqdm import tqdm

# Define model name (Mistral 7B) and task name
model_name = "meta-llama/Meta-Llama-3-8B"
task_name = "mnli"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

# Load Glue metric
metric = load_metric("glue", "mnli")


def evaluate_mnli(glue_dataset):
  """Evaluates MNLI predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset)

  with tqdm(total=total_examples, desc="Evaluating MNLI Dev Set") as progress_bar:
    for inputs in glue_dataset:
      premise = inputs["premise"]
      hypothesis = inputs["hypothesis"]

      # Tokenize premise and hypothesis
      encoding = tokenizer(premise, hypothesis, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric.compute(predictions=predictions, references=labels)
  return results


# Load MNLI dataset from Glue
glue_dataset = load_dataset("kmyoo/glue-mnli-tiny")

# Evaluate model on MNLI dev set
dev_results = evaluate_mnli(glue_dataset["test_matched"])
print(f"MNLI Dev Results: {dev_results}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...

# %%
# Load Glue metric
metric_mrpc = load_metric("glue","mrpc")


def evaluate_mrpc(glue_dataset_mrpc):
  """Evaluates MRPC predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset_mrpc)

  with tqdm(total=total_examples, desc="Evaluating MRPC Dev Set") as progress_bar:
    for inputs in glue_dataset_mrpc:
      sentence1 = inputs["sentence1"]
      sentence2 = inputs["sentence2"]

      # Tokenize sentences
      encoding = tokenizer(sentence1, sentence2, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric_mrpc.compute(predictions=predictions, references=labels)
  return results


# Load MRPC dataset from Glue
glue_dataset_mrpc = load_dataset("glue", "mrpc")

# Select a sample of 100 examples from the validation set
sampled_dataset = glue_dataset_mrpc["test"].select(range(100))  # Select by index

# Evaluate model on the sampled validation set
dev_results_mrpc = evaluate_mrpc(sampled_dataset)
print(f"MRPC Dev Results on 100 Samples: {dev_results_mrpc}")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# ...
# Evaluating MRPC Dev Set: 100%|██████████| 100/100 [08:35<00:00,  5.16s/it]
# MRPC Dev Results on 100 Samples: {'accuracy': 0.56, 'f1': 0.7027027027027027}

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_metric, load_dataset
from tqdm import tqdm

# Define model name (Mistral 7B) and task name
model_name = "meta-llama/Meta-Llama-3-8B"
task_name = "mnli"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/654 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# ...

# %%
# Load Glue metric
metric_mrpc = load_metric("glue","mrpc")


def evaluate_mrpc(glue_dataset_mrpc):
  """Evaluates MRPC predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset_mrpc)

  with tqdm(total=total_examples, desc="Evaluating MRPC Dev Set") as progress_bar:
    for inputs in glue_dataset_mrpc:
      sentence1 = inputs["sentence1"]
      sentence2 = inputs["sentence2"]

      # Tokenize sentences
      encoding = tokenizer(sentence1, sentence2, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric_mrpc.compute(predictions=predictions, references=labels)
  return results


# Load MRPC dataset from Glue
glue_dataset_mrpc = load_dataset("glue", "mrpc")

# Select a sample of 100 examples from the validation set
sampled_dataset = glue_dataset_mrpc["validation"].select(range(100))  # Select by index

# Evaluate model on the sampled validation set
dev_results_mrpc = evaluate_mrpc(sampled_dataset)
print(f"MRPC Dev Results on 100 Samples: {dev_results_mrpc}")
# Out:
# <ipython-input-4-ec8d727ae855>:2: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric_mrpc = load_metric("glue","mrpc")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# ...
# Evaluating MRPC Dev Set: 100%|██████████| 100/100 [08:05<00:00,  4.85s/it]
# MRPC Dev Results on 100 Samples: {'accuracy': 0.69, 'f1': 0.8098159509202454}

# %%
##on validation matched

metric = load_metric("glue", "mnli")


def evaluate_mnli(glue_dataset):
  """Evaluates MNLI predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset)

  with tqdm(total=total_examples, desc="Evaluating MNLI Dev Set") as progress_bar:
    for inputs in glue_dataset:
      premise = inputs["premise"]
      hypothesis = inputs["hypothesis"]

      # Tokenize premise and hypothesis
      encoding = tokenizer(premise, hypothesis, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric.compute(predictions=predictions, references=labels)
  return results


# Load MNLI dataset from Glue
glue_dataset = load_dataset("kmyoo/glue-mnli-tiny")

# Evaluate model on MNLI dev set
dev_results = evaluate_mnli(glue_dataset["validation_matched"])
print(f"MNLI Dev Results: {dev_results}")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Evaluating MNLI Dev Set: 100%|██████████| 100/100 [06:42<00:00,  4.02s/it]
# MNLI Dev Results: {'accuracy': 0.27}

# %%
##on validation mismatched

metric = load_metric("glue", "mnli")


def evaluate_mnli(glue_dataset):
  """Evaluates MNLI predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset)

  with tqdm(total=total_examples, desc="Evaluating MNLI Dev Set") as progress_bar:
    for inputs in glue_dataset:
      premise = inputs["premise"]
      hypothesis = inputs["hypothesis"]

      # Tokenize premise and hypothesis
      encoding = tokenizer(premise, hypothesis, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric.compute(predictions=predictions, references=labels)
  return results


# Load MNLI dataset from Glue
glue_dataset = load_dataset("kmyoo/glue-mnli-tiny")

# Evaluate model on MNLI dev set
dev_results = evaluate_mnli(glue_dataset["validation_mismatched"])
print(f"MNLI Dev Results: {dev_results}")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Evaluating MNLI Dev Set: 100%|██████████| 100/100 [07:20<00:00,  4.41s/it]
# MNLI Dev Results: {'accuracy': 0.28}

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_metric, load_dataset
from tqdm import tqdm

# Define model name (Mistral 7B) and task name
model_name = "meta-llama/Meta-Llama-3-8B"
task_name = "sst-2"

# Load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.6k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# ...

# %%
from collections import Counter

# Load the dataset
glue_dataset_sst2 = load_dataset("glue", "sst2")

# Select a sample of 100 examples from the validation set
sampled_dataset = glue_dataset_sst2["validation"].select(range(100))

# Extract labels
labels = sampled_dataset['label']

# Count the occurrences of each label
label_counts = Counter(labels)

# Print the label counts
print("Label Counts:")
for label, count in label_counts.items():
    print(f"Label {label}: {count}")
# Out:
# Label Counts:
# Label 1: 52
# Label 0: 48

# %%
def evaluate_sst2(glue_dataset_sst2):
  """Evaluates SST-2 predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset_sst2)
  metric_sst2 = load_metric("glue","sst2")

  with tqdm(total=total_examples, desc="Evaluating SST-2 Dev Set") as progress_bar:
    for inputs in glue_dataset_sst2:
      sentence = inputs["sentence"]

      # Tokenize sentence
      encoding = tokenizer(sentence, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric_sst2.compute(predictions=predictions, references=labels)
  return results


# Evaluate model on the sampled validation set
dev_results_sst2 = evaluate_sst2(sampled_dataset)
print(f"SST2 Dev Results on 100 Samples: {dev_results_sst2}")
# Out:
# <ipython-input-10-48158d15058d>:5: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric_sst2 = load_metric("glue","sst2")
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# ...
# Evaluating SST-2 Dev Set: 100%|██████████| 100/100 [04:53<00:00,  2.93s/it]
# SST2 Dev Results on 100 Samples: {'accuracy': 0.52}

# %%
glue_dataset_qnli = load_dataset("glue", "qnli")
metric_qnli=load_metric("glue","qnli")
sampled_dataset = glue_dataset_qnli["validation"].select(range(100))

def evaluate_qnli(glue_dataset_qnli):
  """Evaluates MNLI predictions with Glue metrics and progress bar"""
  predictions, labels = [], []
  total_examples = len(glue_dataset_qnli)

  with tqdm(total=total_examples, desc="Evaluating QNLI Dev Set") as progress_bar:
    for inputs in glue_dataset_qnli:
      entailment = inputs["question"]
      not_entailment = inputs["sentence"]

      # Tokenize premise and hypothesis
      encoding = tokenizer(entailment, not_entailment, return_tensors="pt")

      # Forward pass through model
      outputs = model(**encoding)
      predictions.append(outputs.logits.argmax(-1).item())
      labels.append(inputs["label"])
      progress_bar.update(1)  # Update progress bar for each example

  # Evaluate predictions
  results = metric_qnli.compute(predictions=predictions, references=labels)
  return results


# Evaluate model on the sampled validation set
dev_results_qnli = evaluate_qnli(sampled_dataset)
print(f"QNLI Dev Results on 100 Samples: {dev_results_qnli}")
# Out:
# /usr/local/lib/python3.10/dist-packages/datasets/load.py:759: FutureWarning: The repository for glue contains custom code which must be executed to correctly load the metric. You can inspect the repository content at https://raw.githubusercontent.com/huggingface/datasets/2.19.0/metrics/glue/glue.py
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this metric from the next major release of `datasets`.
#   warnings.warn(
# Evaluating QNLI Dev Set: 100%|██████████| 100/100 [07:30<00:00,  4.50s/it]
# QNLI Dev Results on 100 Samples: {'accuracy': 0.6}
